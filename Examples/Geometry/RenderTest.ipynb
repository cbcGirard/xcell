# %%
import pyvista as pv

msh=pv.read('slice77600_ext10000.vtk')

# %%
pv.themes.DefaultTheme.server_proxy_enabled = True
pv.themes.DefaultTheme.server_proxy_prefix = '/proxy/'


msh.plot(jupyter_backend='trame')
# Out:
# <PIL.Image.Image image mode=RGB size=1024x768>

# %%
msh.plot(jupyter_backend='client')
# Out:
# <PIL.Image.Image image mode=RGB size=1024x768>

# %%
msh.plot(jupyter_backend='server')
# Out:
# <PIL.Image.Image image mode=RGB size=1024x768>

# %%
msh.plot(jupyter_backend='pythreejs')
# Out:
# Renderer(camera=PerspectiveCamera(aspect=1.3333333333333333, children=(DirectionalLight(intensity=0.25, positi…

# %%
msh.plot(jupyter_backend='panel')
# Out:
# /home/benoit/anaconda3/envs/xcell/lib/python3.9/site-packages/pyvista/jupyter/notebook.py:60: UserWarning: Failed to use notebook backend:
#
# Install ``panel`` to use this feature
#
# Falling back to a static output.
#   warnings.warn(
# <PIL.Image.Image image mode=RGB size=1024x768>
